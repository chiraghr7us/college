# %%
''' Name: Chirag Hebbal Rudresh
    ID  : 1002160960
    Course: DASC-5300 Fundamentals of computing
    Title: FOC OOP project

'''
import random
class color: # only for aesthetics
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
class die:
    def roll(self):
        self.value = random.randint(1, 6) # Determine outcome of die roll between 1-6.

class player:
    def __init__(self,is_human):
        self.die = die() # die variable initilized to outcome of dice role to value.
        self.counter = 10  # setting counter=10 to track round wins.

    def die_roll(self):
        self.die.roll() # inheriting Die class attribute into player class.

    def increment_counter(self):
        self.counter += 1 # increment counter if round lost.

    def decrement_counter(self):
        self.counter -= 1 # decrement counter if round won.


class game:
    def __init__(self):
        self.human_player = player(is_human=True) # setting is_human True for human player.
        self.computer_player = player(is_human=False) # setting is_human false for computer.

    def start(self):
        print(color.YELLOW + color.BOLD + "🕹️🎲  Welcome to the Dice Rolling Game!  🎲🕹️"+color.END)
        round_num = 1 # setting round number.
        while self.human_player.counter > 0 and self.computer_player.counter > 0:
            print(color.UNDERLINE+color.BOLD+f"\nRound {round_num} starts!"+color.END)
            input(" Press Enter to roll the dice ▶️")

            self.human_player.die_roll()    # dice roll for human.
            self.computer_player.die_roll() # dice roll for computer.


            print(f"• You rolled a {self.human_player.die.value}") # inheritence of die value from die class to game class.
            print(f"• Computer rolled a {self.computer_player.die.value}")

            if self.human_player.die.value > self.computer_player.die.value: # comparing dice roll values of human and computer.
                print("🏆 You win this round! 🏆")
                self.computer_player.increment_counter()
                self.human_player.decrement_counter()
            elif self.computer_player.die.value > self.human_player.die.value:
                print("🤖  Computer wins this round!  🤖")
                self.human_player.increment_counter()
                self.computer_player.decrement_counter()
            else:
                print("It's a tie!")

            round_num += 1 # incrementing round number.
            print(f"Your counter: {self.human_player.counter} | Computer's counter: {self.computer_player.counter}")
            print("--------------------------------------------------------")


        if self.human_player.counter == 0:  # Winning condition
            print("\nCongratulations! You Won! 🥳 ")
        else:
            print("\nComputer Wins! 💻")


if __name__ == "__main__":
    game().start()    # funtion call to start game
# Out:
# 🕹️🎲  Welcome to the Dice Rolling Game!  🎲🕹️
#
# Round 1 starts!
#  Press Enter to roll the dice ▶️
# • You rolled a 6
# • Computer rolled a 6
# It's a tie!
# Your counter: 10 | Computer's counter: 10
# --------------------------------------------------------
#
# Round 2 starts!
#  Press Enter to roll the dice ▶️
# • You rolled a 5
# • Computer rolled a 1
# 🏆 You win this round! 🏆
# Your counter: 9 | Computer's counter: 11
# --------------------------------------------------------
#
# Round 3 starts!
#  Press Enter to roll the dice ▶️
# • You rolled a 2
# • Computer rolled a 6
# 🤖  Computer wins this round!  🤖
# Your counter: 10 | Computer's counter: 10
# --------------------------------------------------------
#
# Round 4 starts!
#  Press Enter to roll the dice ▶️
# • You rolled a 1
# • Computer rolled a 5
# 🤖  Computer wins this round!  🤖
# Your counter: 11 | Computer's counter: 9
# --------------------------------------------------------
#
# Round 5 starts!
# ...
